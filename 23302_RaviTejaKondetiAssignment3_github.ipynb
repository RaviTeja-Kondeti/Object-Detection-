# %% [markdown]
# ### INSTRUCTIONS
#
# For this assignment, you must use the AWS VM that has been assigned to you.
#
#
# You can refer to this documentation for additional details:
#  - https://www.tensorflow.org/api_docs/python/tf/keras/applications/VGG16
#  - https://www.tensorflow.org/guide/keras/transfer_learning
#
# Then read through the entire framework below once. Note the parts you need to code up.
#
# NOTE: YOU WILL ONLY EDIT ONE CELL (TASKS 1 - 7) FOR THIS ASSIGNMENT AS PER THE INSTRUCTIONS IN THAT CELL

# %%
##### DO NOT EDIT THIS CELL!!!
##### DO NOT IMPORT ANY ADDITIONAL PACKAGES

import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
import cv2

from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras import applications
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras import optimizers

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
##### DO NOT EDIT THIS CELL!!!

### read calteach-101 data 

# set up directory paths 
# data_dir = "..\\..\\datasets\\"
data_dir = "C:\\Users\Administrator\\datasets\\"
input_directory = data_dir+'caltech-101'
images_directory = input_directory+'/'+'images'
gt_summary = input_directory+'/'+'gt_summary.csv'

# read gt_summary for ground truth
df = pd.read_csv(gt_summary)

# pick classes for analysis
classes = ['airplanes', 'Faces', 'Motorbikes']
df = df[df['class'].isin(classes)].reset_index(drop=True)

# get image paths
df['imgpath'] = images_directory+'/'+df['filename']
imgpaths = np.array(df['imgpath'])

# get BBs (scaled 0-1)
df['xmin'] = df['xmin']/df['width']
df['ymin'] = df['ymin']/df['height']
df['xmax'] = df['xmax']/df['width']
df['ymax'] = df['ymax']/df['height']
bboxes = np.array(df[['xmin', 'ymin', 'xmax', 'ymax']].values.tolist(), dtype="float32")

# get class labels and one-hot-encode them
labels = np.array(df['class'])
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
# print(lb.classes_)
# print (lb.transform(lb.classes_))

# get data (images) resized and scaled 0-1
# img_size is based on transfer learning model we plan on using;
# for VGG16, it's 224
data = []
for imgpath in imgpaths:
    image = load_img(imgpath, target_size=(224, 224))
    image = img_to_array(image)
    data.append(image)
data = np.array(data, dtype="float32")/255.0

# split data into train, test, and validate
train_ratio = 0.75
val_ratio = 0.15
test_ratio = 0.10

# first split into train and test
(train_images, test_images, 
 train_labels, test_labels, 
 train_BBs, test_BBs, 
 train_paths, test_paths) = train_test_split(
    data, 
    labels, 
    bboxes, 
    imgpaths, 
    test_size=(1-train_ratio), random_state=42)

# then furhter split test into val and test
(val_images, test_images, 
 val_labels, test_labels, 
 val_BBs, test_BBs, 
 val_paths, test_paths) = train_test_split(
    test_images, 
    test_labels, 
    test_BBs, 
    test_paths, 
    test_size=test_ratio/(test_ratio + val_ratio), random_state=42)

print (train_images.shape, val_images.shape, test_images.shape)
# Out:
# (1524, 224, 224, 3) (305, 224, 224, 3) (204, 224, 224, 3)

# %%
##### THIS IS THE ONLY CELL YOU WILL EDIT PER THE ISNTRUCTIONS BELOW

# load vgg16 backbone
#  - set weights to "imagenet"
#  - set input shape to (224, 224, 3)
#  - do not include the vgg16 top
### (1) YOUR CODE HERE
backbone = applications.VGG16(weights="imagenet", include_top=False, input_shape=(224, 224, 3))


# freeze the backbone
### (2) YOUR CODE HERE
backbone.trainable = False

# flatten output from backbone model
### (3) YOUR CODE HERE
x = layers.Flatten()(backbone.output)

# classification head architecture:
#  - Dense layer with 512 units and relu activation
#  - Dropout layer with rate 0.5
#  - Dense layer with 512 units and relu activation
#  - Dropout layer with rate 0.5
#  - Dense layer with 3 units, softmax activation; name this output layer "clshead"
### (4) YOUR CODE HERE
cls = layers.Dense(512, activation='relu')(x)
cls = layers.Dropout(0.5)(cls)
cls = layers.Dense(512, activation='relu')(cls)
cls = layers.Dropout(0.5)(cls)
cls_output = layers.Dense(3, activation='softmax', name='clshead')(cls)

# regression head architecture:
#  - Dense layer with 128 units and relu activation
#  - Dense layer with 64 units and relu activation
#  - Dense layer with 32 units and relu activation
#  - Dense layer with 4 units, sigmoid activation; name this output layer "reghead"
#    (do you know why we're using output activation of sigmoid here for regression?)
### (5) YOUR CODE HERE
reg = layers.Dense(128, activation='relu')(x)
reg = layers.Dense(64, activation='relu')(reg)
reg = layers.Dense(32, activation='relu')(reg)
reg_output = layers.Dense(4, activation='sigmoid', name='reghead')(reg)

# create model:
#  - set inputs to 'backbone.input'
#  - set outputs to regression output followed by classification output
#     (NOTE: order is important since that is the order in which values will get predicted!)
### (6) YOUR CODE HERE
model = models.Model(inputs=backbone.input, outputs=[reg_output, cls_output])


# compile model
#  - use Adam with learning rate of 1e-4
#  - set clshead metric to 'accuracy' , and reghead metric to 'mse'
#  - set clshead loss to 'categorical_crossentropy' , and reghead loss to 'mean_squared_error'
#  - set clshead weight to 1.0, and reghead weight to 1.0
### (7) YOUR CODE HERE
model.compile(
    optimizer=optimizers.Adam(learning_rate=1e-4),
    loss={
        'clshead': 'categorical_crossentropy',
        'reghead': 'mean_squared_error'
    },
    loss_weights={
        'clshead': 1.0,
        'reghead': 1.0
    },
    metrics={
        'clshead': 'accuracy',
        'reghead': 'mse'
    }
)

# print model summary
# you should get Total params: 31,046,311
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 224, 224, 64  1792        ['input_1[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 224, 224, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 112, 112, 64  0           ['block1_conv2[0][0]']
#                                 )
#
#  block2_conv1 (Conv2D)          (None, 112, 112, 12  73856       ['block1_pool[0][0]']
#                                 8)
#
#  block2_conv2 (Conv2D)          (None, 112, 112, 12  147584      ['block2_conv1[0][0]']
#                                 8)
#
#  block2_pool (MaxPooling2D)     (None, 56, 56, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 56, 56, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 56, 56, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 56, 56, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 28, 28, 256)  0           ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 28, 28, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 28, 28, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 28, 28, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 14, 14, 512)  0           ['block4_conv3[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 14, 14, 512)  2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 14, 14, 512)  2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 14, 14, 512)  2359808     ['block5_conv2[0][0]']
#
#  block5_pool (MaxPooling2D)     (None, 7, 7, 512)    0           ['block5_conv3[0][0]']
#
#  flatten (Flatten)              (None, 25088)        0           ['block5_pool[0][0]']
#
#  dense (Dense)                  (None, 512)          12845568    ['flatten[0][0]']
#
#  dense_2 (Dense)                (None, 128)          3211392     ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 512)          0           ['dense[0][0]']
#
#  dense_3 (Dense)                (None, 64)           8256        ['dense_2[0][0]']
#
#  dense_1 (Dense)                (None, 512)          262656      ['dropout[0][0]']
#
#  dense_4 (Dense)                (None, 32)           2080        ['dense_3[0][0]']
#
#  dropout_1 (Dropout)            (None, 512)          0           ['dense_1[0][0]']
#
#  reghead (Dense)                (None, 4)            132         ['dense_4[0][0]']
#
#  clshead (Dense)                (None, 3)            1539        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 31,046,311
# Trainable params: 16,331,623
# Non-trainable params: 14,714,688
# __________________________________________________________________________________________________

# %%
# %%time

##### DO NOT EDIT THIS CELL!!!

# train model
history = model.fit(
    train_images, {'clshead': train_labels, 'reghead': train_BBs},
    validation_data=(val_images, {'clshead': val_labels, 'reghead': val_BBs}),
    batch_size=32,
    epochs=15,
    verbose=1)
# Out:
# Epoch 1/15
# 48/48 [==============================] - 164s 3s/step - loss: 0.2018 - reghead_loss: 0.0070 - clshead_loss: 0.1949 - reghead_mse: 0.0070 - clshead_accuracy: 0.9193 - val_loss: 0.0036 - val_reghead_loss: 0.0014 - val_clshead_loss: 0.0021 - val_reghead_mse: 0.0014 - val_clshead_accuracy: 1.0000
# Epoch 2/15
# 48/48 [==============================] - 161s 3s/step - loss: 0.0141 - reghead_loss: 0.0010 - clshead_loss: 0.0130 - reghead_mse: 0.0010 - clshead_accuracy: 0.9967 - val_loss: 0.0017 - val_reghead_loss: 0.0012 - val_clshead_loss: 5.1393e-04 - val_reghead_mse: 0.0012 - val_clshead_accuracy: 1.0000
# Epoch 3/15
# 48/48 [==============================] - 159s 3s/step - loss: 0.0063 - reghead_loss: 7.5259e-04 - clshead_loss: 0.0055 - reghead_mse: 7.5259e-04 - clshead_accuracy: 0.9987 - val_loss: 0.0015 - val_reghead_loss: 0.0011 - val_clshead_loss: 3.7568e-04 - val_reghead_mse: 0.0011 - val_clshead_accuracy: 1.0000
# Epoch 4/15
# 48/48 [==============================] - 158s 3s/step - loss: 0.0039 - reghead_loss: 5.5640e-04 - clshead_loss: 0.0033 - reghead_mse: 5.5640e-04 - clshead_accuracy: 0.9993 - val_loss: 0.0012 - val_reghead_loss: 0.0010 - val_clshead_loss: 1.1966e-04 - val_reghead_mse: 0.0010 - val_clshead_accuracy: 1.0000
# Epoch 5/15
# 48/48 [==============================] - 159s 3s/step - loss: 0.0020 - reghead_loss: 4.6290e-04 - clshead_loss: 0.0015 - reghead_mse: 4.6290e-04 - clshead_accuracy: 1.0000 - val_loss: 0.0010 - val_reghead_loss: 9.6313e-04 - val_clshead_loss: 8.5974e-05 - val_reghead_mse: 9.6313e-04 - val_clshead_accuracy: 1.0000
# Epoch 6/15
# 48/48 [==============================] - 161s 3s/step - loss: 0.0065 - reghead_loss: 3.7259e-04 - clshead_loss: 0.0061 - reghead_mse: 3.7259e-04 - clshead_accuracy: 0.9987 - val_loss: 0.0011 - val_reghead_loss: 9.3638e-04 - val_clshead_loss: 1.2179e-04 - val_reghead_mse: 9.3638e-04 - val_clshead_accuracy: 1.0000
# Epoch 7/15
# 48/48 [==============================] - 160s 3s/step - loss: 0.0023 - reghead_loss: 2.9615e-04 - clshead_loss: 0.0020 - reghead_mse: 2.9615e-04 - clshead_accuracy: 1.0000 - val_loss: 0.0010 - val_reghead_loss: 9.4418e-04 - val_clshead_loss: 6.1471e-05 - val_reghead_mse: 9.4418e-04 - val_clshead_accuracy: 1.0000
# Epoch 8/15
# 48/48 [==============================] - 159s 3s/step - loss: 0.0011 - reghead_loss: 2.6967e-04 - clshead_loss: 8.2538e-04 - reghead_mse: 2.6967e-04 - clshead_accuracy: 1.0000 - val_loss: 9.6498e-04 - val_reghead_loss: 9.0150e-04 - val_clshead_loss: 6.3471e-05 - val_reghead_mse: 9.0150e-04 - val_clshead_accuracy: 1.0000
# Epoch 9/15
# 48/48 [==============================] - 158s 3s/step - loss: 9.3211e-04 - reghead_loss: 2.4899e-04 - clshead_loss: 6.8312e-04 - reghead_mse: 2.4899e-04 - clshead_accuracy: 1.0000 - val_loss: 9.4796e-04 - val_reghead_loss: 9.0287e-04 - val_clshead_loss: 4.5091e-05 - val_reghead_mse: 9.0287e-04 - val_clshead_accuracy: 1.0000
# Epoch 10/15
# 48/48 [==============================] - 157s 3s/step - loss: 7.8247e-04 - reghead_loss: 2.1829e-04 - clshead_loss: 5.6418e-04 - reghead_mse: 2.1829e-04 - clshead_accuracy: 1.0000 - val_loss: 9.2546e-04 - val_reghead_loss: 8.8661e-04 - val_clshead_loss: 3.8847e-05 - val_reghead_mse: 8.8661e-04 - val_clshead_accuracy: 1.0000
# Epoch 11/15
# 48/48 [==============================] - 157s 3s/step - loss: 6.9549e-04 - reghead_loss: 2.6728e-04 - clshead_loss: 4.2821e-04 - reghead_mse: 2.6728e-04 - clshead_accuracy: 1.0000 - val_loss: 0.0010 - val_reghead_loss: 0.0010 - val_clshead_loss: 1.6694e-05 - val_reghead_mse: 0.0010 - val_clshead_accuracy: 1.0000
# Epoch 12/15
# 48/48 [==============================] - 155s 3s/step - loss: 6.2010e-04 - reghead_loss: 2.3433e-04 - clshead_loss: 3.8577e-04 - reghead_mse: 2.3433e-04 - clshead_accuracy: 1.0000 - val_loss: 8.8229e-04 - val_reghead_loss: 8.7069e-04 - val_clshead_loss: 1.1596e-05 - val_reghead_mse: 8.7069e-04 - val_clshead_accuracy: 1.0000
# Epoch 13/15
# 48/48 [==============================] - 155s 3s/step - loss: 4.2094e-04 - reghead_loss: 1.7072e-04 - clshead_loss: 2.5022e-04 - reghead_mse: 1.7072e-04 - clshead_accuracy: 1.0000 - val_loss: 8.5979e-04 - val_reghead_loss: 8.4981e-04 - val_clshead_loss: 9.9846e-06 - val_reghead_mse: 8.4981e-04 - val_clshead_accuracy: 1.0000
# Epoch 14/15
# 48/48 [==============================] - 158s 3s/step - loss: 3.8726e-04 - reghead_loss: 1.2989e-04 - clshead_loss: 2.5737e-04 - reghead_mse: 1.2989e-04 - clshead_accuracy: 1.0000 - val_loss: 8.2261e-04 - val_reghead_loss: 8.1381e-04 - val_clshead_loss: 8.8084e-06 - val_reghead_mse: 8.1381e-04 - val_clshead_accuracy: 1.0000
# Epoch 15/15
# 48/48 [==============================] - 157s 3s/step - loss: 2.8065e-04 - reghead_loss: 1.2976e-04 - clshead_loss: 1.5089e-04 - reghead_mse: 1.2976e-04 - clshead_accuracy: 1.0000 - val_loss: 8.3069e-04 - val_reghead_loss: 8.2221e-04 - val_clshead_loss: 8.4736e-06 - val_reghead_mse: 8.2221e-04 - val_clshead_accuracy: 1.0000
# Wall time: 39min 38s

# %%
##### DO NOT EDIT THIS CELL!!!

# model.fit() returns a History object that contains a dictionary with everything that happened during training
# we can use it to plot training/validation loss and training/validation accuracy
history_dict = history.history
print (history_dict.keys())

# plot total loss
loss = history_dict['reghead_loss']
val_loss = history_dict['val_reghead_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'b', label='training reghead_loss')
plt.plot(epochs, val_loss, 'r', label='validation reghead_loss')
plt.title('Training and Validation reghead_loss')
plt.xlabel('Epochs')
plt.ylabel('Reg Loss')
plt.legend()
plt.show()

# plot mse for reghead
mse = history_dict['reghead_mse']
val_mse = history_dict['val_reghead_mse']
epochs = range(1, len(mse) + 1)
plt.plot(epochs, mse, 'b', label='training reghead_mse')
plt.plot(epochs, val_mse, 'r', label='validation reghead_mse')
plt.title('Training and Validation reghead_mse')
plt.xlabel('Epochs')
plt.ylabel('Reg MSE')
plt.legend()
plt.show()

# plot accuracy for clshead
acc = history_dict['clshead_accuracy']
val_acc = history_dict['val_clshead_accuracy']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, 'b', label='training clshead_accuracy')
plt.plot(epochs, val_acc, 'r', label='validation clshead_accuracy')
plt.title('Training and Validation clshead_accuracy')
plt.xlabel('Epochs')
plt.ylabel('CLS Accuracy')
plt.legend()
plt.show()
# Out:
# dict_keys(['loss', 'reghead_loss', 'clshead_loss', 'reghead_mse', 'clshead_accuracy', 'val_loss', 'val_reghead_loss', 'val_clshead_loss', 'val_reghead_mse', 'val_clshead_accuracy'])

# %%
##### DO NOT EDIT THIS CELL!!!

def predict_and_display(image_index=0):

    testimgpath = test_paths[image_index]
    img = cv2.imread(testimgpath)
    (height, width) = img.shape[:2]

    # read and preprocess test image
    image = load_img(testimgpath, target_size=(224, 224))
    image = img_to_array(image) / 255.0
    image = np.expand_dims(image, axis=0)

    # get gt label 
    gt_label = test_labels[image_index]

    # get gt BB
    (gtxmin, gtymin, gtxmax, gtymax) = test_BBs[image_index]

    # scale gt bb to image scale
    gtxmin = int(gtxmin*width)
    gtymin = int(gtymin*height)
    gtxmax = int(gtxmax*width)
    gtymax = int(gtymax*height)

    # predict using model
    # NOTE: these will come out in the same order as you specified in Model outputs
    (pred_BB, pred_label) = model.predict(image)

    # get predicted label
    pred_label = lb.classes_[np.argmax(pred_label, axis=1)][0]

    # get predicted BB
    (pxmin, pymin, pxmax, pymax) = pred_BB[0]

    # scale pred bb to image scale
    pxmin = int(pxmin*width)
    pymin = int(pymin*height)
    pxmax = int(pxmax*width)
    pymax = int(pymax*height)

    # display image along with gt and pred BBs
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cv2.putText(img, pred_label, (pxmin+20, pymin+20), cv2.FONT_HERSHEY_SIMPLEX,0.65, (255, 0, 0), 2)
    cv2.rectangle(img, (pxmin, pymin), (pxmax, pymax), (255,0,0), 3)
    cv2.rectangle(img, (gtxmin, gtymin), (gtxmax, gtymax), (0,255,0), 3)
    plt.imshow(img)
    plt.show()

# predict on a few test images
np.random.seed(42)
for idx in np.random.randint(0, test_images.shape[0], 5):
    predict_and_display(idx)
